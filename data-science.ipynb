# %% [markdown]
# #titulo ##subtitulo
#
# texto negrita: **negrita**
#
# texto cursivo: __cursivo__

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Cartera_Vigente_al_08-02-2020.xls', encoding='latin1')

# %%
df.head(10) #los primeros
# Out:
#                country  region           gdp    school      adfert  chldmort  \
# 0              Algeria  Africa   7300.399902  6.716667    7.300000     34.75
# 1                Benin  Africa   1338.800049  3.100000  111.699997    122.75
# 2             Botswana  Africa  12307.400391  8.600000   52.099998     60.25
# 3         Burkina Faso  Africa   1063.400024  1.300000  124.800003    170.50
# 4              Burundi  Africa    349.200012  2.483333   18.600000    168.50
# 5             Cameroon  Africa   1986.800049  5.650000  127.800003    155.00
# 6           Cape Verde  Africa   3052.199951  3.500000   81.599998     30.00
# 7  Central African Rep  Africa    677.000000  3.383333  106.599998    173.50
# 8                 Chad  Africa   1266.199951  1.500000  164.500000    209.00
# 9              Comoros  Africa   1099.000000  2.800000   58.000000    105.75
#
#         life       pop      urban  femlab   literacy    co2       gini
# ...

# %%
df.tail(10) #los ultimos
# Out:
#               country   region           gdp     school     adfert  chldmort  \
# 184        Micronesia  Oceania   2906.800049   8.800000  25.400000     40.00
# 185             Nauru  Oceania           NaN        NaN  31.200001     45.50
# 186       New Zealand  Oceania  25199.599609  12.366667  30.900000      6.25
# 187             Palau  Oceania           NaN  12.100000  13.800000     15.00
# 188  Papua New Guinea  Oceania   1953.800049   4.116667  66.900002     69.75
# 189             Samoa  Oceania   4012.600098  10.300000  28.299999     26.75
# 190   Solomon Islands  Oceania   2249.199951   4.500000  70.300003     36.00
# 191             Tonga  Oceania   4072.199951  10.133333  22.299999     19.25
# 192            Tuvalu  Oceania           NaN        NaN  23.299999     36.50
# 193           Vanuatu  Oceania   3809.800049   6.700000  54.000000     17.75
#
#           life      pop       urban  femlab   literacy        co2  gini
# ...

# %%
df.sample(10) #Registros aleatorios
# Out:
#          country    region           gdp     school      adfert  chldmort  \
# 87   Afghanistan      Asia    938.400024   2.950000  118.699997    203.00
# 133   Uzbekistan      Asia   2295.600098  10.000000   13.800000     40.25
# 159    Macedonia    Europe   8312.599609   8.200000   22.000000     12.00
# 150       Greece    Europe  26118.000000   9.950000   11.600000      4.00
# 163   Montenegro    Europe   9592.799805  10.600000   18.200001      9.75
# 62    Costa Rica  Americas   9870.000000   8.133333   65.599998     11.25
# 9        Comoros    Africa   1099.000000   2.800000   58.000000    105.75
# 70        Guyana  Americas   2731.000000   7.750000   68.300003     37.00
# 136      Albania    Europe   6832.600098  10.283333   17.900000     17.00
# 154        Italy    Europe  28042.400391   9.816667    6.700000      4.00
#
#           life       pop      urban  femlab   literacy        co2       gini
# 87   47.400002  29501834  21.916666  0.3858        NaN   0.100000        NaN
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True) #inplace reemplaza el data por el nuevo sin las columnas
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-a0b5aa997b95> in <module>
# ----> 1 df.drop(columns=['Unnamed: 0'], inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
df.columns #columnas
# Out:
# Index(['country', 'region', 'gdp', 'school', 'adfert', 'chldmort', 'life',
#        'pop', 'urban', 'femlab', 'literacy', 'co2', 'gini'],
#       dtype='object')

# %%
df['region'] #columnas es especifico
# Out:
# 0       Africa
# 1       Africa
# 2       Africa
# 3       Africa
# 4       Africa
#         ...
# 189    Oceania
# 190    Oceania
# 191    Oceania
# 192    Oceania
# 193    Oceania
# Name: region, Length: 194, dtype: object

# %%
df['region'].unique() #datos unicos
# Out:
# array(['Africa', 'Americas', 'Asia', 'Europe', 'Oceania'], dtype=object)

# %%
df['region'].value_counts() #cuenta los valores agrupandolo
# Out:
# Africa      52
# Asia        49
# Europe      43
# Americas    35
# Oceania     15
# Name: region, dtype: int64

# %%
df['gini'].describe() #analisis agrupado
# Out:
# count    81.000000
# mean     40.477778
# std       8.487874
# min      19.000000
# 25%      34.000000
# 50%      39.700001
# 75%      46.200001
# max      58.500000
# Name: gini, dtype: float64

# %%
estadistica = df['CLIENTE'].describe()
print(estadistica)
#count: cuenta los campos.
#unique: unicos.
#top: el que tiene mas datos.
#freq: cuenta veces esta el que tiene mas datos.
# Out:
# count                 3606
# unique                 251
# top       URBANO CHILE SPA
# freq                   443
# Name: CLIENTE, dtype: object

# %%
df.sort_values(by = ['gdp', 'school'], ascending=False) #Ordenas los datos group by
# Out:
#                   country   region           gdp     school     adfert  \
# 121                 Qatar     Asia  74906.000000   7.150000  16.200001
# 158            Luxembourg   Europe  71141.000000   9.983334  10.100000
# 132  United Arab Emirates     Asia  51992.601562   8.833333  26.700001
# 165                Norway   Europe  48169.398438  12.666667   9.000000
# 93      Brunei Darussalam     Asia  48002.000000   8.483334  25.100000
# ..                    ...      ...           ...        ...        ...
# 116           North Korea     Asia           NaN        NaN   1.000000
# 162                Monaco   Europe           NaN        NaN   1.600000
# 170            San Marino   Europe           NaN        NaN   2.500000
# 185                 Nauru  Oceania           NaN        NaN  31.200001
# 192                Tuvalu  Oceania           NaN        NaN  23.299999
#
#      chldmort       life       pop       urban  femlab    literacy  \
# ...

# %%
for columna in df.columns:  #Estadistica de todo el csv
    print('Estadistica de la columna {0}'.format(columna))
    print(df[columna].describe())
# Out:
# Estadistica de la columna country
# count       194
# unique      194
# top       Italy
# freq          1
# Name: country, dtype: object
# Estadistica de la columna region
# count        194
# unique         5
# top       Africa
# freq          52
# Name: region, dtype: object
# Estadistica de la columna gdp
# count      179.000000
# mean     12118.739193
# std      13942.341217
# min        279.799988
# 25%       2100.300049
# 50%       6932.799805
# 75%      17576.299805
# max      74906.000000
# Name: gdp, dtype: float64
# Estadistica de la columna school
# count    188.000000
# mean       7.459220
# std        2.959589
# min        1.150000
# 25%        5.225000
# 50%        7.950000
# 75%        9.850000
# max       12.700000
# Name: school, dtype: float64
# Estadistica de la columna adfert
# count    194.000000
# mean      51.814433
# std       44.066120
# min        1.000000
# 25%       16.500000
# 50%       39.350000
# 75%       74.375002
# max      207.100006
# ...

# %%
df.describe()  #Estadistica de las columnas numericas
# Out:
#                 gdp      school      adfert    chldmort        life  \
# count    179.000000  188.000000  194.000000  193.000000  194.000000
# mean   12118.739193    7.459220   51.814433   47.650259   68.729295
# std    13942.341217    2.959589   44.066120   52.809400   10.055404
# min      279.799988    1.150000    1.000000    2.250000   45.849998
# 25%     2100.300049    5.225000   16.500000   10.250000   63.745833
# 50%     6932.799805    7.950000   39.350000   24.000000   72.183331
# 75%    17576.299805    9.850000   74.375002   69.750000   75.545835
# max    74906.000000   12.700000  207.100006  209.000000   82.766663
#
#                 pop       urban      femlab    literacy         co2       gini
# count  1.940000e+02  194.000000  177.000000  135.000000  185.000000  81.000000
# mean   3.437752e+07   55.434880    0.691606   81.533148   17.885946  40.477778
# std    1.314004e+08   23.439101    0.182871   19.466359   25.670704   8.487874
# ...

# %%
df['Americas']=0 #crear columnas
df.head()
# Out:
#         country  region           gdp    school      adfert  chldmort  \
# 0       Algeria  Africa   7300.399902  6.716667    7.300000     34.75
# 1         Benin  Africa   1338.800049  3.100000  111.699997    122.75
# 2      Botswana  Africa  12307.400391  8.600000   52.099998     60.25
# 3  Burkina Faso  Africa   1063.400024  1.300000  124.800003    170.50
# 4       Burundi  Africa    349.200012  2.483333   18.600000    168.50
#
#         life       pop      urban  femlab   literacy   co2       gini  \
# 0  72.316666  34172236  64.933334  0.4522  72.599998  15.0        NaN
# 1  54.733334   8237634  41.000000  0.8482  41.700001   1.2        NaN
# 2  52.250000   1941233  59.250000  0.8870  84.099998   9.2        NaN
# 3  53.783333  15308383  23.583334  0.8584  23.600000   0.2        NaN
# 4  48.866665   7821783  10.250000  1.0344  66.599998   0.1  33.299999
#
#    Americas
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
#pasar datos de texto a datos numericos por ejemplo las regiones
for reg in df.
# Out:
#   File "<ipython-input-42-bf2da0157d3e>", line 2
#     for reg in df.
#                   ^
# SyntaxError: invalid syntax

# %%
df['co2'].mean()  #sacar la media
# Out:
# 17.8859457937044

# %%
df['co2_dummy']=np.where(df['co2'].mean(), 1, 0)  #np.where crea las columnas segun la condicion
df['co2_dummy'].value_counts()
# Out:
# 1    194
# Name: co2_dummy, dtype: int64

# %%
df[df['co2_dummy'] == 1]  #buscar con condicion
# Out:
#              country   region           gdp     school      adfert  chldmort  \
# 0            Algeria   Africa   7300.399902   6.716667    7.300000     34.75
# 1              Benin   Africa   1338.800049   3.100000  111.699997    122.75
# 2           Botswana   Africa  12307.400391   8.600000   52.099998     60.25
# 3       Burkina Faso   Africa   1063.400024   1.300000  124.800003    170.50
# 4            Burundi   Africa    349.200012   2.483333   18.600000    168.50
# ..               ...      ...           ...        ...         ...       ...
# 189            Samoa  Oceania   4012.600098  10.300000   28.299999     26.75
# 190  Solomon Islands  Oceania   2249.199951   4.500000   70.300003     36.00
# 191            Tonga  Oceania   4072.199951  10.133333   22.299999     19.25
# 192           Tuvalu  Oceania           NaN        NaN   23.299999     36.50
# 193          Vanuatu  Oceania   3809.800049   6.700000   54.000000     17.75
#
# ...
